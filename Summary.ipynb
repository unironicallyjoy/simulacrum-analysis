# %% [markdown]
# #### Summary Statistics
# sim_sact_drug_detail and sim_sact_cycle

# %%
import pandas as pd
import nump

# %%
sim_sact_drug_detail = pd.read_csv('./data/sim_sact_drug_detail.csv')
sim_sact_drug_detail.head(5)
# Out:
#    MERGED_DRUG_DETAIL_ID  MERGED_CYCLE_ID  ACTUAL_DOSE_PER_ADMINISTRATION  \
# 0               10000001         10000001                           420.0
# 1               10000002         10000002                           420.0
# 2               10000003         10000003                           420.0
# 3               10000004         10000004                             NaN
# 4               10000005         10000005                           420.0
#
#   OPCS_DELIVERY_CODE  ADMINISTRATION_ROUTE ADMINISTRATION_DATE DRUG_GROUP
# 0                NaN                   2.0          2020-04-28  IBRUTINIB
# 1               X731                   2.0          2022-03-27  IBRUTINIB
# 2                NaN                   2.0          2022-01-26  IBRUTINIB
# 3                NaN                   2.0          2019-04-11  IBRUTINIB
# 4                NaN                   2.0          2017-03-31  IBRUTINIB

# %%
print(len(sim_sact_drug_detail))
# Out:
# 7662030

# %%
# get column names in sim_sact_drug_detail
sim_sact_cols = list(sim_sact_drug_detail)

# %%
# get the uiue value in each columns of sim_sact_drug_detail
for item in sim_sact_cols:
    print(item)
    print(sim_sact_drug_detail[item].unique())
# Out:
# MERGED_DRUG_DETAIL_ID
# [ 10000001  10000002  10000003 ... 250017449 250017450 250017451]
# MERGED_CYCLE_ID
# [ 10000001  10000002  10000003 ... 250007459 250007460 250007461]
# ACTUAL_DOSE_PER_ADMINISTRATION
# [420.    nan 560.  ... 121.6 186.5 307.5]
# OPCS_DELIVERY_CODE
# [nan 'X731' 'X729' 'X723' 'X722' 'X713' 'X741' 'X721' 'X701' 'X724' 'X715'
#  '722' 'x724' 'x722' '0' '723' 'x723' 'x721' 'X353' '731' 'X292' 'X714'
#  '721' 'X657' 'x' 'X704' '724' 'X711' 'x731' 'x73' 'X728' '702' 'x729'
#  '729' 'X384' 'X391' 'X720' 'X113' '\\par' 'x701' '711' '704' 'ENHT'
#  'X921' 'X703' '2800' 'x711' 'x703' 'x713' 'X702' 'X383' '715' 'NOTE'
#  '200' '713' 'x702' 'x714' 'X332' 'X708' 'X712' '778' '828' 'Z721' '707'
#  'X' '725' 'X824' 'x292' 'x907' 'x902' 'Tr' 'x739' 'INPT' '722\\' '72 2'
#  '1400' 'x715' '705' 'z724' 'WH' 'X700' 'x772' 'x708' 'Othr' '500' 'X742'
#  'M494' '701' 'X450' 'X442' '1' 'x704' 'N\\A']
# ADMINISTRATION_ROUTE
# ...

# %%
sim_sact_drug_detail.groupby(['ADMINISTRATION_ROUTE']).count()
# Out:
#                       MERGED_DRUG_DETAIL_ID  MERGED_CYCLE_ID  \
# ADMINISTRATION_ROUTE
# 0.0                                   11136            11136
# 1.0                                 4357218          4357218
# 2.0                                 2560804          2560804
# 3.0                                   46997            46997
# 4.0                                   29609            29609
# 5.0                                  442007           442007
# 6.0                                    1991             1991
# 7.0                                     317              317
# 8.0                                      52               52
# 9.0                                   23745            23745
# 10.0                                    227              227
# 11.0                                  24173            24173
# 12.0                                    150              150
# 13.0                                     51               51
# ...

# %%
sim_sact_cycle = pd.read_csv('./data/sim_sact_cycle.csv')
sim_sact_cycle.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14084\433280632.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   sim_sact_cycle = pd.read_csv('./data/sim_sact_cycle.csv')
#    MERGED_REGIMEN_ID  MERGED_CYCLE_ID  CYCLE_NUMBER START_DATE_OF_CYCLE  \
# 0           10030621         10000001             1          2020-04-28
# 1           10030622         10000002             1          2022-03-27
# 2           10030627         10000003             2          2022-01-26
# 3           10030628         10000004             1          2019-04-11
# 4           10030632         10000005             1          2017-03-31
#
#   OPCS_PROCUREMENT_CODE PERF_STATUS_START_OF_CYCLE
# 0                  X713                        NaN
# 1                   NaN                          0
# 2                  X701                          1
# 3                   NaN                        NaN
# 4                   NaN                          0

# %%
print(len(sim_sact_cycle))
# Out:
# 2741674

# %%
# get column names in sim_sact_cycle
sim_cycle_cols = list(sim_sact_cycle)

# %%
# get the uiue value in each columns of sim_sact_cycle
for item in sim_cycle_cols:
    print(item)
    print(sim_sact_cycle[item].unique())
# Out:
# MERGED_REGIMEN_ID
# [ 10030621  10030622  10030627 ... 250009409 250009411 250009412]
# MERGED_CYCLE_ID
# [ 10000001  10000002  10000003 ... 250007459 250007460 250007461]
# CYCLE_NUMBER
# [  1   2   8   7   3   6   5   0  16  12  17  27   4  10  13  14   9  59
#   24  21  19  30  43  11  32  25  38  15  26  61  29  45  34  83  33  20
#   23 128  84  48  18  36  31  22  63  60  35  49  57  56  28  68  70  58
#   37  62  39  54  51  42 102  79  69  93  46  87  44  40 117 115  76  55
#   85  74  89  50  41  65  53  75  91  71  47  77  67  64  80  52  72 143
#   95  99  73  66  82  98  97 155 123 146 137  86 170  78  92  88 116  81
#  118 129  90 149 161 101 104 135 152 154 103 159 131 174 160 100  96  94
#  121 107 106 172 112 133 140 164 139 171 120 105 166 173 145 136 156 158
#  163 157 119 148 175 144 114 124 169 125 111 162 108 113 130 110 127 109
#  141 122 132 138 134 126 165 167 235 240 225 247 231 229 289 153 205 191
# ...
